# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/mac/Downloads/Coffe_shop_cleaned.csv')

# %%
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0            10.0      card  38.70          Latte     Morning     Fri
# 1            12.0      card  38.70  Hot Chocolate   Afternoon     Fri
# 2            12.0      card  38.70  Hot Chocolate   Afternoon     Fri
# 3            13.0      card  28.90      Americano   Afternoon     Fri
# 4            13.0      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3467         10.0      card  35.76     Cappuccino     Morning     Sun
# 3468         14.0      card  35.76          Cocoa   Afternoon     Sun
# 3469         14.0      card  35.76          Cocoa   Afternoon     Sun
# 3470         15.0      card  25.96      Americano   Afternoon     Sun
# 3471         18.0      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time  \
# ...

# %%
# Предположим, твой DataFrame называется df
df = df[['Time_of_Day', 'coffee_name', 'money', 'Weekday', 'Month_name', 'Date', 'purchase_level', 'Weekdaysort', 'Monthsort']]

# %%
df.to_csv('cafe_shop.csv', index=False)

# %%
print(df.head())
# Out:
#   Time_of_Day    coffee_name  money Weekday Month_name        Date  \
# 0     Morning          Latte   38.7     Fri        Mar  2024-03-01
# 1   Afternoon  Hot Chocolate   38.7     Fri        Mar  2024-03-01
# 2   Afternoon  Hot Chocolate   38.7     Fri        Mar  2024-03-01
# 3   Afternoon      Americano   28.9     Fri        Mar  2024-03-01
# 4   Afternoon          Latte   38.7     Fri        Mar  2024-03-01
#
#   purchase_level  Weekdaysort  Monthsort
# 0           high          5.0        3.0
# 1           high          5.0        3.0
# 2           high          5.0        3.0
# 3            low          5.0        3.0
# 4           high          5.0        3.0
